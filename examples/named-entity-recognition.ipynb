# %% [markdown]
# # Named Entity Recognition
# A simple example on how to use the vector database for linking named entities to Wikidata items

# %%
import requests

HEADERS = {
    'User-Agent': 'NER/1.0 (embeddings@wikimedia.de)'
}
LIMIT = 50
LANG = 'en'

# Define the entity to link to Wikidata along with the statement where it appeats
statement = 'Man Playing Flute" is a mezzotint engraving created by John Smith in the late 17th century'
named_entity = 'John Smith'

# %% [markdown]
# ### Get potential items from Wikidata that refer to the named entity

# %%
# Search for candidates with keyword search

params = {
    "action": "wbsearchentities",
    "format": "json",
    "type": "item",
    "language": LANG,
    "search": named_entity,
    "limit": LIMIT
}
candidates = requests.get(
    "https://www.wikidata.org/w/api.php",
    params,
    headers=HEADERS
)
candidates = candidates.json()

# %% [markdown]
# ### Score each candidate with vector similarity

# %%
# Use vector similarity score with the original statement to rank candidates

candidate_ids = [candidate['id'] for candidate in candidates.get('search', [])]

params = {
    "query": statement,
    "qid": ','.join(candidate_ids),
    "lang": LANG
}
candidate_scores = requests.get(
    'https://wd-vectordb.wmcloud.org/similarity-score',
    params=params,
    headers=HEADERS,
)
candidate_scores = candidate_scores.json()

# %%
highest_score_qid = candidate_scores[0]['QID']
highest_score_candidate = next((c for c in candidates['search'] if c["id"] == highest_score_qid), None)

print(highest_score_candidate['label'])
print(highest_score_candidate['id'])
# Out:
# John Smith
# Q6258328

# %% [markdown]
# ### Why do we need keyword search?

# %%
# When querying the full vector search with the statement.
# Results will be focused more on the context rather than the entity name.
# In this example, we get items relating to the art piece rather than the artist "John Smith".
# Keyword search is therefore necessary to narrow down to candidates that match the entity name. Then we can rank results by vector similarity while considering the context of the full statement.

items = requests.get(
    'https://wd-vectordb.wmcloud.org/item/query',
    params={
        'query': statement,
        'lang': LANG,
        'rerank': True
    },
    headers=HEADERS,
)
items = items.json()
items
# Out:
# [{'QID': 'Q26693267',
#   'similarity_score': 0.74336195,
#   'rrf_score': 0.0196078431372549,
#   'source': 'Vector Search',
#   'reranker_score': 0.45132649},
#  {'QID': 'Q15994751',
#   'similarity_score': 0.67061293,
#   'rrf_score': 0.011363636363636364,
#   'source': 'Vector Search',
#   'reranker_score': 0.30074561},
#  {'QID': 'Q6258270',
#   'similarity_score': 0.6875923,
#   'rrf_score': 0.016666666666666666,
#   'source': 'Vector Search',
#   'reranker_score': 0.22405544},
#  {'QID': 'Q6232556',
#   'similarity_score': 0.6992055,
#   'rrf_score': 0.017857142857142856,
#   'source': 'Vector Search',
#   'reranker_score': 0.22270013},
#  {'QID': 'Q21460534',
#   'similarity_score': 0.6740238,
#   'rrf_score': 0.012658227848101266,
#   'source': 'Vector Search',
#   'reranker_score': 0.22135067},
#  {'QID': 'Q16239552',
#   'similarity_score': 0.66782826,
#   'rrf_score': 0.010752688172043012,
#   'source': 'Vector Search',
#   'reranker_score': 0.20181322},
#  {'QID': 'Q29789017',
#   'similarity_score': 0.67584056,
#   'rrf_score': 0.013333333333333334,
#   'source': 'Vector Search',
#   'reranker_score': 0.17106119},
#  {'QID': 'Q5462960',
#   'similarity_score': 0.695625,
#   'rrf_score': 0.017241379310344827,
#   'source': 'Vector Search',
#   'reranker_score': 0.15817434},
#  {'QID': 'Q53729333',
#   'similarity_score': 0.70017564,
#   'rrf_score': 0.01818181818181818,
#   'source': 'Vector Search',
#   'reranker_score': 0.15713684},
#  {'QID': 'Q20814008',
#   'similarity_score': 0.69625247,
#   'rrf_score': 0.017543859649122806,
#   'source': 'Vector Search',
#   'reranker_score': 0.14706451},
#  {'QID': 'Q3228161',
#   'similarity_score': 0.6729496,
#   'rrf_score': 0.012345679012345678,
#   'source': 'Vector Search',
#   'reranker_score': 0.13206615},
#  {'QID': 'Q5462950',
#   'similarity_score': 0.6826414,
#   'rrf_score': 0.015384615384615385,
#   'source': 'Vector Search',
#   'reranker_score': 0.13028541},
#  {'QID': 'Q5315801',
#   'similarity_score': 0.68518955,
#   'rrf_score': 0.015625,
#   'source': 'Vector Search',
#   'reranker_score': 0.12940273},
#  {'QID': 'Q5462940',
#   'similarity_score': 0.6724893,
#   'rrf_score': 0.012048192771084338,
#   'source': 'Vector Search',
#   'reranker_score': 0.12592275},
#  {'QID': 'Q3490097',
#   'similarity_score': 0.68206394,
#   'rrf_score': 0.014925373134328358,
#   'source': 'Vector Search',
#   'reranker_score': 0.12252322},
#  {'QID': 'Q129677068',
#   'similarity_score': 0.7170298,
#   'rrf_score': 0.018867924528301886,
#   'source': 'Vector Search',
#   'reranker_score': 0.11920292},
#  {'QID': 'Q20487676',
#   'similarity_score': 0.6821263,
#   'rrf_score': 0.015151515151515152,
#   'source': 'Vector Search',
#   'reranker_score': 0.11279541},
#  {'QID': 'Q125463952',
#   'similarity_score': 0.6667874,
#   'rrf_score': 0.010416666666666666,
#   'source': 'Vector Search',
#   'reranker_score': 0.1112412},
#  {'QID': 'Q23700935',
#   'similarity_score': 0.66482776,
#   'rrf_score': 0.010101010101010102,
#   'source': 'Vector Search',
#   'reranker_score': 0.10230471},
#  {'QID': 'Q27685858',
#   'similarity_score': 0.721192,
#   'rrf_score': 0.019230769230769232,
#   'source': 'Vector Search',
#   'reranker_score': 0.09947021},
#  {'QID': 'Q12119414',
#   'similarity_score': 0.69133335,
#   'rrf_score': 0.01694915254237288,
#   'source': 'Vector Search',
#   'reranker_score': 0.09807932},
#  {'QID': 'Q125572652',
#   'similarity_score': 0.6860131,
#   'rrf_score': 0.016129032258064516,
#   'source': 'Vector Search',
#   'reranker_score': 0.09268778},
#  {'QID': 'Q6234398',
#   'similarity_score': 0.70092046,
#   'rrf_score': 0.018518518518518517,
#   'source': 'Vector Search',
#   'reranker_score': 0.09138211},
#  {'QID': 'Q6259219',
#   'similarity_score': 0.66775656,
#   'rrf_score': 0.010638297872340425,
#   'source': 'Vector Search',
#   'reranker_score': 0.08632348},
#  {'QID': 'Q52154440',
#   'similarity_score': 0.6760421,
#   'rrf_score': 0.013513513513513514,
#   'source': 'Vector Search',
#   'reranker_score': 0.08269734},
#  {'QID': 'Q11824964',
#   'similarity_score': 0.6676777,
#   'rrf_score': 0.010526315789473684,
#   'source': 'Vector Search',
#   'reranker_score': 0.08151976},
#  {'QID': 'Q30338536',
#   'similarity_score': 0.6852554,
#   'rrf_score': 0.015873015873015872,
#   'source': 'Vector Search',
#   'reranker_score': 0.07921032},
#  {'QID': 'Q4241968',
#   'similarity_score': 0.6695011,
#   'rrf_score': 0.011111111111111112,
#   'source': 'Vector Search',
#   'reranker_score': 0.07807817},
#  {'QID': 'Q3490124',
#   'similarity_score': 0.6761743,
#   'rrf_score': 0.0136986301369863,
#   'source': 'Vector Search',
#   'reranker_score': 0.07696084},
#  {'QID': 'Q60300562',
#   'similarity_score': 0.6812925,
#   'rrf_score': 0.014492753623188406,
#   'source': 'Vector Search',
#   'reranker_score': 0.07369627},
#  {'QID': 'Q26970763',
#   'similarity_score': 0.6862805,
#   'rrf_score': 0.01639344262295082,
#   'source': 'Vector Search',
#   'reranker_score': 0.0715912},
#  {'QID': 'Q1336324',
#   'similarity_score': 0.67621005,
#   'rrf_score': 0.013888888888888888,
#   'source': 'Vector Search',
#   'reranker_score': 0.06954174},
#  {'QID': 'Q6273452',
#   'similarity_score': 0.6747427,
#   'rrf_score': 0.01282051282051282,
#   'source': 'Vector Search',
#   'reranker_score': 0.06954174},
#  {'QID': 'Q31745074',
#   'similarity_score': 0.66836333,
#   'rrf_score': 0.010869565217391304,
#   'source': 'Vector Search',
#   'reranker_score': 0.06954174},
#  {'QID': 'Q3133279',
#   'similarity_score': 0.67755866,
#   'rrf_score': 0.014285714285714285,
#   'source': 'Vector Search',
#   'reranker_score': 0.06560484},
#  {'QID': 'Q7190180',
#   'similarity_score': 0.6709422,
#   'rrf_score': 0.011764705882352941,
#   'source': 'Vector Search',
#   'reranker_score': 0.06560484},
#  {'QID': 'Q66489760',
#   'similarity_score': 0.67543745,
#   'rrf_score': 0.012987012987012988,
#   'source': 'Vector Search',
#   'reranker_score': 0.06465349},
#  {'QID': 'Q3937529',
#   'similarity_score': 0.66535634,
#   'rrf_score': 0.01020408163265306,
#   'source': 'Vector Search',
#   'reranker_score': 0.06187599},
#  {'QID': 'Q3882040',
#   'similarity_score': 0.6641108,
#   'rrf_score': 0.01,
#   'source': 'Vector Search',
#   'reranker_score': 0.06187599},
#  {'QID': 'Q2719356',
#   'similarity_score': 0.6710777,
#   'rrf_score': 0.011904761904761904,
#   'source': 'Vector Search',
#   'reranker_score': 0.06097518},
#  {'QID': 'Q6222921',
#   'similarity_score': 0.66559803,
#   'rrf_score': 0.010309278350515464,
#   'source': 'Vector Search',
#   'reranker_score': 0.06097518},
#  {'QID': 'Q14849071',
#   'similarity_score': 0.68180966,
#   'rrf_score': 0.014705882352941176,
#   'source': 'Vector Search',
#   'reranker_score': 0.06008665},
#  {'QID': 'Q47519779',
#   'similarity_score': 0.67351633,
#   'rrf_score': 0.0125,
#   'source': 'Vector Search',
#   'reranker_score': 0.05749328},
#  {'QID': 'Q11883468',
#   'similarity_score': 0.67627734,
#   'rrf_score': 0.014084507042253521,
#   'source': 'Vector Search',
#   'reranker_score': 0.05261895},
#  {'QID': 'Q124344786',
#   'similarity_score': 0.66867006,
#   'rrf_score': 0.01098901098901099,
#   'source': 'Vector Search',
#   'reranker_score': 0.05033063},
#  {'QID': 'Q6233205',
#   'similarity_score': 0.6707137,
#   'rrf_score': 0.011494252873563218,
#   'source': 'Vector Search',
#   'reranker_score': 0.04958903},
#  {'QID': 'Q28449831',
#   'similarity_score': 0.6699416,
#   'rrf_score': 0.011235955056179775,
#   'source': 'Vector Search',
#   'reranker_score': 0.0433658},
#  {'QID': 'Q21609105',
#   'similarity_score': 0.6708142,
#   'rrf_score': 0.011627906976744186,
#   'source': 'Vector Search',
#   'reranker_score': 0.04208773},
#  {'QID': 'Q6273119',
#   'similarity_score': 0.6754769,
#   'rrf_score': 0.013157894736842105,
#   'source': 'Vector Search',
#   'reranker_score': 0.03963884},
#  {'QID': 'Q6193309',
#   'similarity_score': 0.67274195,
#   'rrf_score': 0.012195121951219513,
#   'source': 'Vector Search',
#   'reranker_score': 0.03258974}]
